# %%
import numpy as np
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
X_test = np.array([[1,2,3],[2,5,6],[5,5,6]])
pca.fit(X_test)

# Transfrom X_test into n_components
scores = pca.transform(X_test)

# Doing pca.transform(X_test) by hand
X_hat_manual = pca.components_ @ (X_test - pca.mean_).T

# Should be the same
X_test, (scores @ pca.components_) + pca.mean_
